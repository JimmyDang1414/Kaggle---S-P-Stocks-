# %%
#General modules
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', 5)

# %%
#Import the data. 
sp500stocks = pd.read_csv("sp500_stocks.csv")
sp500companies = pd.read_csv("sp500_companies.csv")
sp500index = pd.read_csv("sp500_index.csv")

# %%
#check the data 
sp500stocks
# Out:
#                Date Symbol   Adj Close       Close        High         Low  \
# 0        2009-12-31    MMM         NaN         NaN         NaN         NaN
# 1        2010-01-04    MMM   59.318886   83.019997   83.449997   82.669998
# ...             ...    ...         ...         ...         ...         ...
# 1617143  2022-09-29    ZTS  150.949997  150.949997  152.559998  150.000000
# 1617144  2022-09-30    ZTS  148.289993  148.289993  152.029999  148.039993
#
#                Open     Volume
# 0               NaN        NaN
# 1         83.089996  3043700.0
# ...             ...        ...
# 1617143  152.059998  1642000.0
# 1617144  150.419998  2437200.0
#
# [1617145 rows x 8 columns]

# %%
sp500companies
# Out:
#     Exchange Symbol                        Shortname  \
# 0        NMS   AAPL                       Apple Inc.
# 1        NMS   MSFT            Microsoft Corporation
# ..       ...    ...                              ...
# 491      NYQ   NCLH  Norwegian Cruise Line Holdings
# 492      NYQ    VNO             Vornado Realty Trust
#
#                                 Longname             Sector  \
# 0                             Apple Inc.         Technology
# 1                  Microsoft Corporation         Technology
# ..                                   ...                ...
# 491  Norwegian Cruise Line Holdings Ltd.  Consumer Cyclical
# 492                 Vornado Realty Trust        Real Estate
#
#                     Industry  Currentprice      Marketcap        Ebitda  \
# 0       Consumer Electronics        138.20  2267364458496  1.295570e+11
# 1    Software—Infrastructure        232.90  1748608483328  9.798300e+10
# ...

# %%
sp500index
# Out:
#             Date   S&P500
# 0     2012-10-01  1444.49
# 1     2012-10-02  1445.75
# ...          ...      ...
# 2515  2022-09-29  3640.47
# 2516  2022-09-30  3585.62
#
# [2517 rows x 2 columns]
